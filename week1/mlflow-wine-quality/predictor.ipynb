# %%
import mlflow
import os
mlflow.set_tracking_uri("http://127.0.0.1:5000")
logged_model = 'runs:/658a8f9d32dc4195aff589d9cd7a74fb/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.

import pandas as pd
wine_path = "wine-quality-20percent.csv"
data = pd.read_csv(wine_path)
data = data.drop(["quality"], axis=1)
predictions = loaded_model.predict(pd.DataFrame(data))
print("end")
data['quality-predict'] = predictions
# Out:
# end

# %%
data = pd.read_csv(wine_path)
data['quality-predict'] = predictions

# %%
print("First model predictions:")
data.head(20)
# Out:
# First model predictions:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.6             0.260         0.00            10.2      0.038
# 1             6.3             0.280         0.30             6.6      0.208
# 2             6.4             0.290         0.30             6.5      0.209
# 3             7.2             0.340         0.23             8.9      0.105
# 4             7.1             0.390         0.39            11.1      0.034
# 5             6.9             0.260         0.29             4.2      0.043
# 6             6.1             0.240         0.25             1.6      0.044
# 7             5.9             0.250         0.24             7.4      0.044
# 8             6.1             0.240         0.27            11.5      0.050
# 9             6.5             0.220         0.27             1.6      0.039
# 10            6.2             0.260         0.29             2.0      0.036
# ...

# %%
print("best model predictions:")
data.head(20)
# Out:
# best model predictions:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.6             0.260         0.00            10.2      0.038
# 1             6.3             0.280         0.30             6.6      0.208
# 2             6.4             0.290         0.30             6.5      0.209
# 3             7.2             0.340         0.23             8.9      0.105
# 4             7.1             0.390         0.39            11.1      0.034
# 5             6.9             0.260         0.29             4.2      0.043
# 6             6.1             0.240         0.25             1.6      0.044
# 7             5.9             0.250         0.24             7.4      0.044
# 8             6.1             0.240         0.27            11.5      0.050
# 9             6.5             0.220         0.27             1.6      0.039
# 10            6.2             0.260         0.29             2.0      0.036
# ...

# %%
print("Worts model predictions:")
data.head(20)
# Out:
# Worts model predictions:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.6             0.260         0.00            10.2      0.038
# 1             6.3             0.280         0.30             6.6      0.208
# 2             6.4             0.290         0.30             6.5      0.209
# 3             7.2             0.340         0.23             8.9      0.105
# 4             7.1             0.390         0.39            11.1      0.034
# 5             6.9             0.260         0.29             4.2      0.043
# 6             6.1             0.240         0.25             1.6      0.044
# 7             5.9             0.250         0.24             7.4      0.044
# 8             6.1             0.240         0.27            11.5      0.050
# 9             6.5             0.220         0.27             1.6      0.039
# 10            6.2             0.260         0.29             2.0      0.036
# ...

# %%
# The data set used in this example is from http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.

import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet


warnings.filterwarnings("ignore")
np.random.seed(40)

# Read the wine-quality csv file (make sure you're running this from the root of MLflow!)
wine_path = os.path.join("wine-quality.csv")
data = pd.read_csv(wine_path)

# Split the data into training and test sets. (0.75, 0.25) split.
train, test = train_test_split(data)

# The predicted column is "quality" which is a scalar from [3, 9]
train_x = train.drop(["quality"], axis=1)
test_x = test.drop(["quality"], axis=1)
train_y = train[["quality"]]
test_y = test[["quality"]]

# %%
print ("test_x", test_x)
